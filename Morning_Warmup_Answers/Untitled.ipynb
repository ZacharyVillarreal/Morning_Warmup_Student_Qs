# %% [markdown]
# 1. Write a SQL query to calculate the average price of all products of the manufacturer which code is 16:
#
# Table Name: **item_mast**
#
#
# ![image.png](attachment:222a0e4e-5cdd-4a75-96c5-3c4a3bee1780.png)

# %% [markdown]
# **Answer**:<br>
#
# SELECT AVG(pro_price) <br>
# FROM item_mast <br>
# WHERE pro_com=16;<br>

# %% [markdown]
# 2.
